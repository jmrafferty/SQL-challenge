# %%
# Import the SQL database into Pandas. 

import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
postgresStr = ("postgresql://postgres:password@localhost:5432/EmployeeSQL")
engine = create_engine(postgresStr)
connection = engine.connect()

# %%
all_employees = pd.read_sql('SELECT * FROM employees', connection, parse_dates=["birth_date", "hire_date"])
all_employees.head(5)
# Out:
#    emp_no birth_date first_name last_name gender  hire_date
# 0   10001 1953-09-02     Georgi   Facello      M 1986-06-26
# 1   10002 1964-06-02    Bezalel    Simmel      F 1985-11-21
# 2   10003 1959-12-03      Parto   Bamford      M 1986-08-28
# 3   10004 1954-05-01  Chirstian   Koblick      M 1986-12-01
# 4   10005 1955-01-21    Kyoichi  Maliniak      M 1989-09-12

# %%
salaries_df = pd.read_sql('SELECT * FROM salaries', connection, parse_dates=["birth_date", "hire_date"])

# sort salaries from greates to least
salaries_df.sort_values(by='salary', axis=0, ascending=False, inplace=True, kind='quicksort', na_position='last')



salaries_df.head()
# Out:
#         emp_no  salary   from_date     to_date
# 105024  205000  129492  1991-10-12  1992-10-11
# 34187    44188  127238  1991-03-16  1992-03-15
# 244780  444756  127041  1999-06-14  2000-06-13
# 258326  458302  126703  1998-10-05  1999-10-05
# 27557    37558  125469  1989-02-23  1990-02-23

# %%
#Create a histogram to visualize the most common salary ranges for employees.
salaries_df.hist(column='salary')
plt.title("Most Common Employee Salary Ranges")
plt.ylabel("Number of Employees")
plt.xlabel("Salary Ranges ($)")
# Out:
# Text(0.5, 0, 'Salary Ranges ($)')

# %%
titles_df = pd.read_sql('SELECT * FROM titles', connection, parse_dates=["birth_date", "hire_date"])

titles_df.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
#Create a bar chart of average salary by title.

merged_df = pd.merge(salaries_df, titles_df, on='emp_no')
merged_df.head()
# Out:
#    emp_no  salary from_date_x   to_date_x         title from_date_y  \
# 0  205000  129492  1991-10-12  1992-10-11  Senior Staff  1999-10-12
# 1  205000  129492  1991-10-12  1992-10-11         Staff  1991-10-12
# 2   44188  127238  1991-03-16  1992-03-15  Senior Staff  1991-03-16
# 3  444756  127041  1999-06-14  2000-06-13         Staff  1999-06-14
# 4  458302  126703  1998-10-05  1999-10-05         Staff  1998-10-05
#
#     to_date_y
# 0  9999-01-01
# 1  1999-10-12
# 2  9999-01-01
# 3  9999-01-01
# 4  9999-01-01

# %%
#merged_df.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-8b7b95995a62> in <module>
# ----> 1 merged_df.plot.bar()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#     946             >>> ax = df.plot.bar(x='lifespan', rot=0)
#     947         """
# --> 948         return self(kind="bar", x=x, y=y, **kwargs)
#     949
#     950     def barh(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     279         self._compute_plot_data()
#     280         self._setup_subplots()
# --> 281         self._make_plot()
#     282         self._add_table()
#     283         self._make_legend()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1393                     label=label,
#    1394                     log=self.log,
# -> 1395                     **kwds
#    1396                 )
#    1397             self._add_legend_handle(rect, label, index=i)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1318     @classmethod
#    1319     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1320         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1321
#    1322     @property
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2436             elif orientation == 'horizontal':
#    2437                 r.sticky_edges.x.append(l)
# -> 2438             self.add_patch(r)
#    2439             patches.append(r)
#    2440
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    1968         self._set_artist_props(p)
#    1969         if p.get_clip_path() is None:
# -> 1970             p.set_clip_path(self.patch)
#    1971         self._update_patch_limits(p)
#    1972         self.patches.append(p)
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     730             if isinstance(path, Rectangle):
#     731                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 732                                                path.get_transform())
#     733                 self._clippath = None
#     734                 success = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, bbox, transform, **kwargs)
#    1012         self._bbox = bbox
#    1013         self._transform = transform
# -> 1014         self.set_children(bbox, transform)
#    1015         self._points = None
#    1016
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in set_children(self, *children)
#     178             ref = weakref.ref(self, lambda ref, sid=id(self),
#     179                                         target=child._parents: target.pop(sid))
# --> 180             child._parents[id(self)] = ref
#     181
#     182     if DEBUG:
#
# KeyboardInterrupt:
